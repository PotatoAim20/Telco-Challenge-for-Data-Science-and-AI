# %%
# === Step 1: Installing required Python packages ===
# !pip install --upgrade --user huggingface_hub
# !pip install -U transformers
# !pip install sentencepiece
# !pip install regex
# !pip install --upgrade scikit-learn==1.6.1 --quiet --no-deps
# !pip install fastapi nest-asyncio pyngrok uvicorn

# === Step 2: Configure ngrok with your authentication token ===
# !ngrok config add-authtoken 2xokRxcJjkaR0ViWZEMUagyHO2Y_3aR8eAqcofLd3kr4ALiza

# === Step 3: Authenticate with Hugging Face Hub ===
from huggingface_hub import login

# NOTE: This is a private Hugging Face access token.
# I've left it exposed here to make it easier to run the notebook directly for testing purposes.
# Make sure to revoke and replace it before sharing or deploying publicly.
login(token="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")

# %%
# Step 1: Clone the full GitHub repository
# !git clone https://github.com/PotatoAim20/Telco-Challenge-for-Data-Science-and-AI.git

# Step 2: Change directory to the Chatbot_Pipeline folder
# %cd Telco-Challenge-for-Data-Science-and-AI/Chatbot_Pipeline

# Step 3: Run the chatbot pipeline script
# !python run.py
